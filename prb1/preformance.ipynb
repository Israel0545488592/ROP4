# %%
from sol import *

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn-v0_8-dark')

# %%
sizes = range(1, 15)

ratio = lambda x, y : x / y

run_times = [ratio( * CVX_vs_NP(size, 10)) for size in sizes]

plt.plot(sizes, run_times)
plt.xlabel('size of the matrix')
plt.ylabel('ratio of cvxpy\'s run time to numpy\'s')
plt.show()

# %% [markdown]
# seems like cvxpy preformes much wrose but linearly so
#
# that should be excpected, cvxpy is built forconvex optimization and numpy for linear algebra
